# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    print("model_grade:", model_grade)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)
    print("syntax_score:", syntax_score)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# model_grade: {'strengths': ['Regex pattern correctly captures all three required groups (timestamp, level, message) with proper bracket escaping', 'Handles multi-word messages and special characters effectively due to greedy matching with (.+)', 'Clean, readable code with appropriate error handling via None return for non-matching inputs'], 'weaknesses': ['Regex uses (.+) which is greedy and could match trailing whitespace; (.+?)$ would be more precise', 'No validation of timestamp format (ISO 8601) or log level values (ERROR, WARN, INFO, DEBUG) after extraction', 'Missing edge case handling: empty messages, leading/trailing whitespace, and malformed entries are not validated'], 'reasoning': 'The solution successfully meets the core requirement of parsing the specified log format and extracting the three components. The regex pattern is sound for the happy path. However, it lacks validation to ensure extracted values conform to expected formats (ISO 8601 timestamps, valid log levels). The greedy matching could theoretically cause issues with unusual message content. For production use, adding timestamp validation and log level verification would strengthen the solution.', 'score': 7}
# syntax_score: 0
# model_grade: {'strengths': ['Valid JSON syntax with correct AWS S3 bucket policy structure following the 2012-10-17 policy language version', 'Properly configured Principal, Action, and Resource fields to grant public read access to all objects in the specified bucket', 'Includes descriptive Sid identifier for clarity and auditability of the policy statement'], 'weaknesses': ['No security warnings or disclaimers about the risks of public read access, which could lead to unintended data exposure', 'Missing optional but recommended Condition element that could restrict access by IP, time, or other factors for enhanced security', 'Does not address bucket-level permissions (s3:ListBucket action) which may be needed for some public access scenarios'], 'reasoning': 'The solution correctly implements a functional S3 bucket policy for public read access with valid JSON structure and proper AWS policy format. However, it lacks security considerations and optional enhancements that would be prudent in a production context. The policy as written will work as intended but represents a permissive security posture without safeguards.', 'score': 7}
# syntax_score: 10
# model_grade: {'strengths': ["Regex pattern correctly validates the format: 'i-' prefix followed by 8 or 17 hexadecimal characters", 'Clean, concise implementation using appropriate Python standard library', 'Correctly uses bool() conversion to ensure boolean return type'], 'weaknesses': ['Does not handle edge cases gracefully - will raise AttributeError if None is passed instead of returning False', 'Missing input validation for non-string types, which could cause runtime errors', 'No docstring or type hints explanation for expected behavior with invalid inputs'], 'reasoning': "The solution correctly implements the core requirement with a well-constructed regex pattern that validates both 8 and 17 character hex formats. However, it fails the 'handle edge cases gracefully' criterion by not defensively handling None or non-string inputs. A production-quality solution should either validate input types first or use try-except handling. The fix would be minimal (adding a type check like `if not isinstance(instance_id, str): return False` at the start).", 'score': 6}
# syntax_score: 10
# Average score: 6.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\nimport json\n\ndef parse_cloudwatch_log(log_entry):\n    pattern = r'\\[([^\\]]+)\\] \\[([^\\]]+)\\] (.+)'\n    match = re.match(pattern, log_entry)\n    \n    if match:\n        return {\n            \"timestamp\": match.group(1),\n            \"level\": match.group(2),\n            \"message\": match.group(3)\n        }\n    return None\n\n# Example usage\nlog_entry = \"[2024-01-15T10:30:45Z] [ERROR] Database connection failed\"\nresult = parse_cloudwatch_log(log_entry)\nprint(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudWatch log entry and extract the timestamp, log level, and message. The log format is: '[TIMESTAMP] [LEVEL] Message content here'",
#       "format": "regex",
#       "solution_criteria": "The regex should correctly capture three groups: timestamp (ISO 8601 format), log level (ERROR, WARN, INFO, DEBUG), and the message text. Should handle multi-word messages and special characters."
#     },
#     "score": 3.5,
#     "reasoning": "The solution successfully meets the core requirement of parsing the specified log format and extracting the three components. The regex pattern is sound for the happy path. However, it lacks validation to ensure extracted values conform to expected formats (ISO 8601 timestamps, valid log levels). The greedy matching could theoretically cause issues with unusual message content. For production use, adding timestamp validation and log level verification would strengthen the solution."
#   },
#   {
#     "output": "\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"PublicReadGetObject\",\n      \"Effect\": \"Allow\",\n      \"Principal\": \"*\",\n      \"Action\": \"s3:GetObject\",\n      \"Resource\": \"arn:aws:s3:::my-public-bucket/*\"\n    }\n  ]\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS S3 bucket policy that allows public read access to all objects in the bucket named 'my-public-bucket'",
#       "format": "json",
#       "solution_criteria": "Valid JSON with correct AWS S3 bucket policy structure, including Version, Statement array with proper Effect, Principal, Action, and Resource fields. Should follow AWS policy document format."
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly implements a functional S3 bucket policy for public read access with valid JSON structure and proper AWS policy format. However, it lacks security considerations and optional enhancements that would be prudent in a production context. The policy as written will work as intended but represents a permissive security posture without safeguards."
#   },
#   {
#     "output": "\nimport re\n\ndef is_valid_ec2_instance_id(instance_id: str) -> bool:\n    pattern = r'^i-[0-9a-f]{8}(?:[0-9a-f]{9})?$'\n    return bool(re.match(pattern, instance_id))\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS EC2 instance ID string and returns True if it matches the valid AWS instance ID format (i-followed by 8 or 17 hexadecimal characters), False otherwise",
#       "format": "python",
#       "solution_criteria": "Function should validate instance IDs like 'i-1234567890abcdef0' and 'i-12345678', reject invalid formats, and handle edge cases like None or empty strings gracefully."
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly implements the core requirement with a well-constructed regex pattern that validates both 8 and 17 character hex formats. However, it fails the 'handle edge cases gracefully' criterion by not defensively handling None or non-string inputs. A production-quality solution should either validate input types first or use try-except handling. The fix would be minimal (adding a type check like `if not isinstance(instance_id, str): return False` at the start)."
#   }
# ]
